# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone\
# 0    man        True  NaN  Southampton    no  False\
# 1  woman       False    C    Cherbourg   yes  False\
# 2  woman       False  NaN  Southampton   yes   True\
# 3  woman       False    C  Southampton   yes  False\
# 4    man        True  NaN  Southampton    no   True\

# %% [markdown]
# ## Filtering Rows using Conditions

# %%
## List out the Person who have travelled in Third Class

# %%
# Method 1: Location(loc) function

# %%
dfnew=df.loc[df['class']=='Third']
dfnew
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
# Method 2: Query Function

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone\
# 0    man        True  NaN  Southampton    no  False\
# 1  woman       False    C    Cherbourg   yes  False\
# 2  woman       False  NaN  Southampton   yes   True\
# 3  woman       False    C  Southampton   yes  False\
# 4    man        True  NaN  Southampton    no   True\

# %%
newdf = df.query("sex== 'male'")
newdf
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
# Method3 DataFrame Way

# %%
## Female alive passanger

# %%
dfalivefemale = df[(df.alive == "yes") & (df.sex == "female")]
dfalivefemale
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
## DataFrame Filter by rows position and columns name

# %%
df.loc[df.index[0:10],["pclass","who"]]
# Out:
#    pclass    who
# 0       3    man
# 1       1  woman
# 2       3  woman
# 3       1  woman
# 4       3    man
# 5       3    man
# 6       1    man
# 7       3  child
# 8       3  woman
# 9       2  child

# %%
## Apply Lambda function to filter rows

# %%
## List out the fare greater than 7.0000

# %%
df.loc[lambda df: df['fare'] > 7.0000]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
## Filter Rows with Specific Column Using Conditions

# %%
df.loc[df['age'] < 30.0 ,'who']
# Out:
# 0        man
# 2      woman
# 7      child
# 8      woman
# 9      child
#        ...
# 883      man
# 884      man
# 886      man
# 887    woman
# 889      man
# Name: who, Length: 384, dtype: object

# %%
## Filter columns by name

# %%
 df[['pclass', 'sex','age','alive']]
# Out:
#      pclass     sex   age alive
# 0         3    male  22.0    no
# 1         1  female  38.0   yes
# 2         3  female  26.0   yes
# 3         1  female  35.0   yes
# 4         3    male  35.0    no
# ..      ...     ...   ...   ...
# 886       2    male  27.0    no
# 887       1  female  19.0   yes
# 888       3  female   NaN    no
# 889       1    male  26.0   yes
# 890       3    male  32.0    no
#
# [891 rows x 4 columns]

# %%
## Select rows whose column value does not equal a specific value

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
## List out column 'alive' value not equalto 'Yes' whose town is "Southampton"

# %%
 df.loc[(df.alive != "yes") & (df.embark_town == "Southampton")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
## The tilde operator negates the  values in the DataFrame:

# %%
## Filter columns of 'Who' is 'child' using tilde operator

# %%
childpassanger= df[~df['who'].str.contains('man')]
childpassanger
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.00      3      1  21.0750        S   Third
# 9           1       2  female  14.00      1      0  30.0708        C  Second
# 10          1       3  female   4.00      1      1  16.7000        S   Third
# 14          0       3  female  14.00      0      0   7.8542        S   Third
# 16          0       3    male   2.00      4      1  29.1250        Q   Third
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 831         1       2    male   0.83      1      1  18.7500        S  Second
# 850         0       3    male   4.00      4      2  31.2750        S   Third
# 852         0       3  female   9.00      1      1  15.2458        C   Third
# 869         1       3    male   4.00      1      1  11.1333        S   Third
# 875         1       3  female  15.00      0      0   7.2250        C   Third
#
# ...

# %%
## Filter Non-Missing Data in Pandas Dataframe

# %%
nonmissingdata= df[df.deck.notnull()]
nonmissingdata
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %%
## Select rows having values starting from letter 'f' in sex columns

# %%
df[df['sex'].str[0] == 'f']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...

# %% [markdown]
# ### List Comprehension Method for Filtering

# %%
## Let's filter the rows of male who did not survive

# %%
 df.iloc[[index for index,row in df.iterrows() if row['sex'] == 'male' and row['survived'] == 0]]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 881         0       3  male  33.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone\
# ...
