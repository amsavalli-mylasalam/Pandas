# %%
import pandas as pd

# %%
df=pd.read_csv('Temple.csv')

# %%
df
# Out:
#                                            templeName  \
# 0           Badrinath Temple | Badrinath, Uttarakhand
# 1           Kedarnath Temple | Kedarnath, Uttarakhand
# 2             Gangotri Temple | Gangotri, Uttarakhand
# 3           Yamunotri Temple | Yamunotri, Uttarakhand
# 4                Har Ki Pauri | Haridwar, Uttarakhand
# 5   Neelkanth Mahadev Temple | Rishikesh, Uttarakhand
# 6           Naina Devi Temple | Nainital, Uttarakhand
# 7   Kashi Vishwanath Temple | Varanasi, Uttar Pradesh
# 8                    Golden Temple | Amritsar, Punjab
# 9         Amarnath Temple | Pahalgam, Jammu & Kashmir
# 10  Vaishno Devi Temple | Vaishno Devi, Jammu & Ka...
# 11  Shankaracharya Temple | Srinagar, Jammu & Kashmir
# 12               Akshardham Temple | New Delhi, Delhi
# 13                    Lotus Temple | New Delhi, Delhi
# 14                    Birla Mandir | New Delhi, Delhi
# 15                    ISKON Temple | New Delhi, Delhi
# ...

# %%
## Columns of dataframe

# %%
df.columns
# Out:
# Index(['templeName', 'Description', 'Location', 'Coordinates',
#        'DistanceFromMumbai(Km)', 'DistanceFromNewDelhi(Km)',
#        'DistanceFromChennai(Km)', 'DistanceFromKolkata(Km)'],
#       dtype='object')

# %%
## Index (Rows) of the dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=53, step=1)

# %%
## Series or column

# %%
df.templeName
# Out:
# 0             Badrinath Temple | Badrinath, Uttarakhand
# 1             Kedarnath Temple | Kedarnath, Uttarakhand
# 2               Gangotri Temple | Gangotri, Uttarakhand
# 3             Yamunotri Temple | Yamunotri, Uttarakhand
# 4                  Har Ki Pauri | Haridwar, Uttarakhand
# 5     Neelkanth Mahadev Temple | Rishikesh, Uttarakhand
# 6             Naina Devi Temple | Nainital, Uttarakhand
# 7     Kashi Vishwanath Temple | Varanasi, Uttar Pradesh
# 8                      Golden Temple | Amritsar, Punjab
# 9           Amarnath Temple | Pahalgam, Jammu & Kashmir
# 10    Vaishno Devi Temple | Vaishno Devi, Jammu & Ka...
# 11    Shankaracharya Temple | Srinagar, Jammu & Kashmir
# 12                 Akshardham Temple | New Delhi, Delhi
# 13                      Lotus Temple | New Delhi, Delhi
# 14                      Birla Mandir | New Delhi, Delhi
# 15                      ISKON Temple | New Delhi, Delhi
# 16         Jwalamukhi Temple | Kangra, Himachal Pradesh
# ...

# %%
## Accessing Multiple Series - 2 dimensions

# %%
df[['templeName','Description','Location']]
# Out:
#                                            templeName  \
# 0           Badrinath Temple | Badrinath, Uttarakhand
# 1           Kedarnath Temple | Kedarnath, Uttarakhand
# 2             Gangotri Temple | Gangotri, Uttarakhand
# 3           Yamunotri Temple | Yamunotri, Uttarakhand
# 4                Har Ki Pauri | Haridwar, Uttarakhand
# 5   Neelkanth Mahadev Temple | Rishikesh, Uttarakhand
# 6           Naina Devi Temple | Nainital, Uttarakhand
# 7   Kashi Vishwanath Temple | Varanasi, Uttar Pradesh
# 8                    Golden Temple | Amritsar, Punjab
# 9         Amarnath Temple | Pahalgam, Jammu & Kashmir
# 10  Vaishno Devi Temple | Vaishno Devi, Jammu & Ka...
# 11  Shankaracharya Temple | Srinagar, Jammu & Kashmir
# 12               Akshardham Temple | New Delhi, Delhi
# 13                    Lotus Temple | New Delhi, Delhi
# 14                    Birla Mandir | New Delhi, Delhi
# 15                    ISKON Temple | New Delhi, Delhi
# ...

# %%
## head() function is used to get the first n rows

# %%
df.head()
# Out:
#                                   templeName  \
# 0  Badrinath Temple | Badrinath, Uttarakhand
# 1  Kedarnath Temple | Kedarnath, Uttarakhand
# 2    Gangotri Temple | Gangotri, Uttarakhand
# 3  Yamunotri Temple | Yamunotri, Uttarakhand
# 4       Har Ki Pauri | Haridwar, Uttarakhand
#
#                                          Description    Location  \
# 0  The Badrinath temple also known as Badrinaraya...   Badrinath
# 1  Located at the highest altitude among the Char...   Kedarnath
# 2  The birthplace of the holy River Ganges is in ...    Gangotri
# 3  Located opposite to Gangotri is the sacred shr...   Yamunotri
# 4  As one of the oldest living cities of India, H...    Haridwar
#
#                 Coordinates  DistanceFromMumbai(Km)  DistanceFromNewDelhi(Km)  \
# 0  (30.7423302, 79.4930256)             1454.013555                323.309362
# 1  (30.7345609, 79.0673204)             1434.105557                295.986734
# ...

# %%
## Finding datatypes of columns in DataFrame

# %%
[f'Data types of {column} is {df[column].dtype}'for column in df.columns]
# Out:
# ['Data types of templeName is object',
#  'Data types of Description is object',
#  'Data types of Location is object',
#  'Data types of Coordinates is object',
#  'Data types of DistanceFromMumbai(Km) is float64',
#  'Data types of DistanceFromNewDelhi(Km) is float64',
#  'Data types of DistanceFromChennai(Km) is float64',
#  'Data types of DistanceFromKolkata(Km) is float64']

# %%
df.dtypes
# Out:
# templeName                   object
# Description                  object
# Location                     object
# Coordinates                  object
# DistanceFromMumbai(Km)      float64
# DistanceFromNewDelhi(Km)    float64
# DistanceFromChennai(Km)     float64
# DistanceFromKolkata(Km)     float64
# dtype: object

# %%
## Shape & Size of the dataframe

# %%
df.shape
# Out:
# (53, 8)

# %%
df.size
# Out:
# 424

# %%
## Information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   templeName                53 non-null     object
#  1   Description               53 non-null     object
#  2   Location                  52 non-null     object
#  3   Coordinates               53 non-null     object
#  4   DistanceFromMumbai(Km)    53 non-null     float64
#  5   DistanceFromNewDelhi(Km)  53 non-null     float64
#  6   DistanceFromChennai(Km)   53 non-null     float64
#  7   DistanceFromKolkata(Km)   53 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 3.4+ KB

# %%
##Get Values of Data Frame in List of List

# %%
df.values
# Out:
# array([['Badrinath Temple | Badrinath, Uttarakhand',
#         'The Badrinath temple also known as Badrinarayan is dedicated to Lord Vishnu, particularly his duel forms of Nar and Narayan. Badrinath was re-established as a major pilgrimage site by Adi Shankara in the 9th century. In the 17th century the temple was expanded by the Garhwal kings. Lord Vishnu is found here in a meditative posture flanked by Nar and Narayan. Badrinath is a significant pilgrimage centre for the Vaishnavites. It is also the most important of the Char Dhams.',
#         ' Badrinath', '(30.7423302, 79.4930256)', 1454.0135545769983,
#         323.3093622930583, 1957.065908907751, 1265.717343618258],
#        ['Kedarnath Temple | Kedarnath, Uttarakhand',
# ...

# %%
## Get Axes of the Data Frame

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=53, step=1),
#  Index(['templeName', 'Description', 'Location', 'Coordinates',
#         'DistanceFromMumbai(Km)', 'DistanceFromNewDelhi(Km)',
#         'DistanceFromChennai(Km)', 'DistanceFromKolkata(Km)'],
#        dtype='object')]

# %%
df.axes[1]
# Out:
# Index(['templeName', 'Description', 'Location', 'Coordinates',
#        'DistanceFromMumbai(Km)', 'DistanceFromNewDelhi(Km)',
#        'DistanceFromChennai(Km)', 'DistanceFromKolkata(Km)'],
#       dtype='object')

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=53, step=1)

# %%
## Number of Dimensions in the Data Frame

# %%
df.ndim
# Out:
# 2

# %%
## Memory Usage of Each Columns in Bytes

# %%
df.memory_usage()
# Out:
# Index                       128
# templeName                  424
# Description                 424
# Location                    424
# Coordinates                 424
# DistanceFromMumbai(Km)      424
# DistanceFromNewDelhi(Km)    424
# DistanceFromChennai(Km)     424
# DistanceFromKolkata(Km)     424
# dtype: int64

# %%
## Set index

# %%
dfTemple=df.copy()
dfTemple=dfTemple.set_index('templeName')
dfTemple
# Out:
#                                                                                           Description  \
# templeName
# Badrinath Temple | Badrinath, Uttarakhand           The Badrinath temple also known as Badrinaraya...
# Kedarnath Temple | Kedarnath, Uttarakhand           Located at the highest altitude among the Char...
# Gangotri Temple | Gangotri, Uttarakhand             The birthplace of the holy River Ganges is in ...
# Yamunotri Temple | Yamunotri, Uttarakhand           Located opposite to Gangotri is the sacred shr...
# Har Ki Pauri | Haridwar, Uttarakhand                As one of the oldest living cities of India, H...
# Neelkanth Mahadev Temple | Rishikesh, Uttarakhand   Located on the outskirts of Rishikesh atop a h...
# Naina Devi Temple | Nainital, Uttarakhand           Nainital is named after Naina Devi. It is cons...
# Kashi Vishwanath Temple | Varanasi, Uttar Pradesh   Kashi Vishwanath Temple is located on the bank...
# ...

# %%
## Re-index rows

# %%
dftemplesample=dfTemple.head()
dftemplesample
# Out:
#                                                                                  Description  \
# templeName
# Badrinath Temple | Badrinath, Uttarakhand  The Badrinath temple also known as Badrinaraya...
# Kedarnath Temple | Kedarnath, Uttarakhand  Located at the highest altitude among the Char...
# Gangotri Temple | Gangotri, Uttarakhand    The birthplace of the holy River Ganges is in ...
# Yamunotri Temple | Yamunotri, Uttarakhand  Located opposite to Gangotri is the sacred shr...
# Har Ki Pauri | Haridwar, Uttarakhand       As one of the oldest living cities of India, H...
#
#                                              Location  \
# templeName
# Badrinath Temple | Badrinath, Uttarakhand   Badrinath
# Kedarnath Temple | Kedarnath, Uttarakhand   Kedarnath
# Gangotri Temple | Gangotri, Uttarakhand      Gangotri
# Yamunotri Temple | Yamunotri, Uttarakhand   Yamunotri
# Har Ki Pauri | Haridwar, Uttarakhand         Haridwar
#
# ...

# %%
newindex=['Gangotri Temple | Gangotri, Uttarakhand','Badrinath Temple | Badrinath, Uttarakhand','Har Ki Pauri | Haridwar, Uttarakhand','Yamunotri Temple | Yamunotri, Uttarakhand']

# %%
dftemplesample.reindex(newindex)
# Out:
#                                                                                  Description  \
# templeName
# Gangotri Temple | Gangotri, Uttarakhand    The birthplace of the holy River Ganges is in ...
# Badrinath Temple | Badrinath, Uttarakhand  The Badrinath temple also known as Badrinaraya...
# Har Ki Pauri | Haridwar, Uttarakhand       As one of the oldest living cities of India, H...
# Yamunotri Temple | Yamunotri, Uttarakhand  Located opposite to Gangotri is the sacred shr...
#
#                                              Location  \
# templeName
# Gangotri Temple | Gangotri, Uttarakhand      Gangotri
# Badrinath Temple | Badrinath, Uttarakhand   Badrinath
# Har Ki Pauri | Haridwar, Uttarakhand         Haridwar
# Yamunotri Temple | Yamunotri, Uttarakhand   Yamunotri
#
#                                                         Coordinates  \
# templeName
# Gangotri Temple | Gangotri, Uttarakhand    (30.9943684, 78.9398699)
# ...

# %%
## Reindex the columns

# %%
dftemplesample.reindex(columns=['Location','Description','Coordinates','DistanceFromMumbai(Km)','DistanceFromChennai(Km)','DistanceFromKolkata(Km)'])
# Out:
#                                              Location  \
# templeName
# Badrinath Temple | Badrinath, Uttarakhand   Badrinath
# Kedarnath Temple | Kedarnath, Uttarakhand   Kedarnath
# Gangotri Temple | Gangotri, Uttarakhand      Gangotri
# Yamunotri Temple | Yamunotri, Uttarakhand   Yamunotri
# Har Ki Pauri | Haridwar, Uttarakhand         Haridwar
#
#                                                                                  Description  \
# templeName
# Badrinath Temple | Badrinath, Uttarakhand  The Badrinath temple also known as Badrinaraya...
# Kedarnath Temple | Kedarnath, Uttarakhand  Located at the highest altitude among the Char...
# Gangotri Temple | Gangotri, Uttarakhand    The birthplace of the holy River Ganges is in ...
# Yamunotri Temple | Yamunotri, Uttarakhand  Located opposite to Gangotri is the sacred shr...
# Har Ki Pauri | Haridwar, Uttarakhand       As one of the oldest living cities of India, H...
#
# ...

# %%
## Reset Index

# %%
dftemplesample.reset_index()
# Out:
#                                   templeName  \
# 0  Badrinath Temple | Badrinath, Uttarakhand
# 1  Kedarnath Temple | Kedarnath, Uttarakhand
# 2    Gangotri Temple | Gangotri, Uttarakhand
# 3  Yamunotri Temple | Yamunotri, Uttarakhand
# 4       Har Ki Pauri | Haridwar, Uttarakhand
#
#                                          Description    Location  \
# 0  The Badrinath temple also known as Badrinaraya...   Badrinath
# 1  Located at the highest altitude among the Char...   Kedarnath
# 2  The birthplace of the holy River Ganges is in ...    Gangotri
# 3  Located opposite to Gangotri is the sacred shr...   Yamunotri
# 4  As one of the oldest living cities of India, H...    Haridwar
#
#                 Coordinates  DistanceFromMumbai(Km)  DistanceFromNewDelhi(Km)  \
# 0  (30.7423302, 79.4930256)             1454.013555                323.309362
# 1  (30.7345609, 79.0673204)             1434.105557                295.986734
# ...
